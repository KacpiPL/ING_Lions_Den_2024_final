# %%
import pandas as pd

# %%
in_time_fe = pd.read_csv('../data/output/fe/out_of_time_fe.csv')
out_time_fe = pd.read_csv('../data/output/fe/out_of_time_fe.csv')

# %%
in_time_fe
# Out:
#         Unnamed: 0  Customer_id  No_dependants  Time_in_address  \
# 0                0     31264719              3             9.93
# 1                1     33263992              1             9.54
# 2                2     31153663              1            11.41
# 3                3     34161420              1             3.42
# 4                4     33407849              2            25.98
# ...            ...          ...            ...              ...
# 156865      159995     34145361              1            16.50
# 156866      159996     37691952              0             2.81
# 156867      159997     35630042              0            11.25
# 156868      159998     32549616              1            10.52
# 156869      159999     38303999              1             5.48
#
#         Time_in_current_job  Credit_cards  Debit_cards  Active_accounts  \
# 0                      1.39             0            3                1
# ...

# %%
out_time_fe
# Out:
#         Unnamed: 0  Customer_id  No_dependants  Time_in_address  \
# 0                0     31264719              3             9.93
# 1                1     33263992              1             9.54
# 2                2     31153663              1            11.41
# 3                3     34161420              1             3.42
# 4                4     33407849              2            25.98
# ...            ...          ...            ...              ...
# 156865      159995     34145361              1            16.50
# 156866      159996     37691952              0             2.81
# 156867      159997     35630042              0            11.25
# 156868      159998     32549616              1            10.52
# 156869      159999     38303999              1             5.48
#
#         Time_in_current_job  Credit_cards  Debit_cards  Active_accounts  \
# 0                      1.39             0            3                1
# ...
